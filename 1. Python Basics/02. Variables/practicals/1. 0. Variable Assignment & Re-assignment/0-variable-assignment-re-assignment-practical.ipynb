# %% [markdown]
# <a href="https://colab.research.google.com/github/LDC-creator/data_engineering_course/blob/main/2.%20Variables/practicals/1.%200.%20Variable%20Assignment%20%26%20Re-assignment/0-variable-assignment-re-assignment-practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable Naming

# %%
# Setup cell - Run this first
# This cell sets up all dependencies and imports for this practical

# !wget -q "https://raw.githubusercontent.com/LDC-creator/data_engineering_course/refs/heads/main/2.%20Variables/practicals/1.%200.%20Variable%20Assignment%20%26%20Re-assignment/marking_system.py"

# Import marking system
import marking_system
import importlib
importlib.reload(marking_system)

# Setup custom error handling
import sys
ipython = get_ipython()

def hide_traceback(exc_tuple=None, filename=None, tb_offset=None, exception_only=False, running_compiled_code=False):
    etype, value, tb = sys.exc_info()
    value.__cause__ = None
    return ipython._showtraceback(etype, '❌ ' + f'\033[91m{value}', ipython.InteractiveTB.get_exception_only(etype, '❌ ' + f'\033[91m{value}'))

ipython.showtraceback = hide_traceback

print('✅ Setup complete! You can now run the rest of the notebook.')
# Out:
# ✅ Setup complete! You can now run the rest of the notebook.

# %% [markdown]
# ### 1: Define a variable called `my_variable` and assign it the value `23`

# %%
# TODO:: Create a variable named my_variable and set it equal to 23

# %%
#@title #### Run this cell to check your solution { display-mode: "form", run: "auto" }

assert "my_variable" in globals(), "You haven't defined the variable 'my_variable'."

marking_system.check_step_1(my_variable)
# Out:
# ✔ Well done!

# %% [markdown]
# ### 2. Print the value of `my_variable`

# %%
# TODO:: Print the value of my_variable using the print function

# %%
#@title #### Copy and paste your line of code in this form to check your solution { display-mode: "form", run: "auto" }

your_code = "" #@param {type:"string"}
marking_system.check_step_2(your_code=your_code)
# Out:
# AssertionError: ❌ Your code should contain a print statement.

# %% [markdown]
# ### 3. Write a new line of code that reassigns `my_variable` to have the value `98`

# %%
# TODO:: Create a variable named my_variable and set it equal to 98

# %%
#@title #### Run this cell to check your solution { display-mode: "form", run: "auto" }

assert "my_variable" in globals(), "You haven't defined the variable 'my_variable'."

marking_system.check_step_3(my_variable)

# %% [markdown]
# ### 4. Print the value of `my_variable` again
#
# _Notice that the value of `my_variable` has changed._

# %%
# TODO::

# %%
#@title Copy and paste your line of code in this form to check your solution { display-mode: "form", run: "auto" }

your_code = "" #@param {type:"string"}
marking_system.check_step_4(your_code=your_code)
